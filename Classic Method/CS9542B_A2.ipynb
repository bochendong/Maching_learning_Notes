# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

from sklearn.decomposition import PCA

# %%
image_set = pd.read_csv("faces.dat",sep="\s+",header=None)
image_set = image_set.to_numpy()

# %%
plt.imshow(np.abs(image_set[199].reshape(64, 64).T), 'gray')

# %%
plt.imshow(np.abs(image_set[99].reshape(64, 64).T), 'gray')

# %%
pca = PCA().fit(image_set)

eigen_value = pca.explained_variance_
plt.plot(range(0, 400), eigen_value)

# %%
pca = PCA().fit(image_set)

com = pca.components_
fig = plt.figure(figsize=(12,12))
fig.add_subplot(231)
plt.imshow(np.abs(com[0].reshape(64, 64).T), 'gray')
plt.xlabel(1)
fig.add_subplot(232)
plt.imshow(np.abs(com[1].reshape(64, 64).T), 'gray')
plt.xlabel(2)
fig.add_subplot(233)
plt.imshow(np.abs(com[2].reshape(64, 64).T), 'gray')
plt.xlabel(3)
fig.add_subplot(234)
plt.imshow(np.abs(com[3].reshape(64, 64).T), 'gray')
plt.xlabel(4)
fig.add_subplot(235)
plt.imshow(np.abs(com[4].reshape(64, 64).T), 'gray')
plt.xlabel(5)
# Out:
# Text(0.5, 0, '5')

# %%
def reconstructed_with_pca(n):
    pca = PCA(n_components=n).fit(image_set)
    x_new = pca.transform (image_set)
    recdata = pca.inverse_transform(x_new)

    return recdata

reconstructed_10 = reconstructed_with_pca(10)
reconstructed_100 = reconstructed_with_pca(100)
reconstructed_200 = reconstructed_with_pca(200)
reconstructed_399 = reconstructed_with_pca(399)

# %%
fig = plt.figure(figsize=(12,12))
fig.add_subplot(221)   #top left
plt.imshow(reconstructed_10[99].reshape(64, 64).T, cmap='gray')
fig.add_subplot(222)   #top right
plt.imshow(reconstructed_100[99].reshape(64, 64).T, cmap='gray')
fig.add_subplot(223)   #bottom left
plt.imshow(reconstructed_200[99].reshape(64, 64).T, cmap='gray')
fig.add_subplot(224)   #bottom right 
plt.imshow(reconstructed_399[99].reshape(64, 64).T, cmap='gray')
